# %%
# %cd /content
# %ls -sla
# Out:
# /content
# total 20
# 4 drwxr-xr-x 1 root root 4096 Sep 30 04:59 ./
# 4 drwxr-xr-x 1 root root 4096 Sep 30 04:47 ../
# 4 drwxr-xr-x 4 root root 4096 Sep 25 18:24 .config/
# 4 drwx------ 6 root root 4096 Sep 30 04:59 drive/
# 4 drwxr-xr-x 1 root root 4096 Sep 25 18:24 sample_data/

# %%
# %cd /content
# %rm -rf src
# %cp -rf "/content/drive/MyDrive/HCMUS/Grad/Master/Học phần/HP3/LLM/Project/Codes/src" /content/src
# Out:
# /content

# %%
# %cd /content/src
# %ls -sla
# Out:
# /content/src
# total 56
#  4 drwx------ 5 root root  4096 Sep 30 05:01 ./
#  4 drwxr-xr-x 1 root root  4096 Sep 30 05:00 ../
#  4 drwx------ 4 root root  4096 Sep 30 05:01 data/
#  4 drwx------ 7 root root  4096 Sep 30 05:01 .git/
#  4 -rw------- 1 root root  3151 Sep 30 05:01 .gitignore
# 20 -rw------- 1 root root 16725 Sep 30 05:01 LICENSE
#  4 -rw------- 1 root root    43 Sep 30 05:01 README.md
#  4 -rw------- 1 root root    29 Sep 30 05:01 requirements.txt
#  4 drwx------ 3 root root  4096 Sep 30 05:01 source/
#  4 -rw------- 1 root root    27 Sep 30 05:01 start.ps1

# %%
# %cd /content/src
# %pip install -r requirements.txt
# Out:
# /content/src
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 71.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.0 MB/s eta 0:00:00
# ...

# %%
# !ollama version
# Out:
# /bin/bash: line 1: ollama: command not found

# %%
# !ollama list
# Out:
# /bin/bash: line 1: ollama: command not found
